# %% [markdown]
# <a href="https://colab.research.google.com/github/VicenteMirannda/projeto/blob/main/treinamento_modelo_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dansbecker/food-101")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'food-101' dataset.
# Path to dataset files: /kaggle/input/food-101

# %%
# !pip install ultralytics -q

from ultralytics import YOLO

# 2. Carregar o modelo Nano (é o mais rápido para ver se tudo funciona)
model = YOLO('yolov8n.pt')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.4 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
